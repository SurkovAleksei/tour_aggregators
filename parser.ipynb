# %%
import requests
from bs4 import BeautifulSoup

# Запрос к сайту
url = "https://bolshayastrana.com/tury"
response = requests.get(url)

# Проверка
if response.status_code == 200:
    # Объект HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Данные из tour-preview__title
    titles = soup.find_all('tour-preview__title')
    for title in titles:
        print(title.text)
else:
    print(f"Ошибка: {response.status_code}")
    # Находим все элементы с турами
tours = soup.find_all('div', class_='tour-preview')

for tour in tours:
    # Название тура
    name = tour.find('div', itemprop='name').get_text(strip=True)
    
    # URL тура
    url = tour.find('meta', itemprop='url')['content']
    full_url = f"https://bolshayastrana.com{url}" 
    
    # Цена
    price = tour.find('span', itemprop='price').get_text(strip=True)
    
    # Дата
    dates = tour.find('span', class_='tour-preview__details-caption').get_text(strip=True)
    
    # Описание
    description = tour.find('div', itemprop='description').get_text(strip=True)
    
    # Местоположение
    location = tour.find('div', class_='tour-preview__location').get_text(strip=True)
    
    # Тип тура
    tour_type = tour.find('a', class_='as-tag is-small').get_text(strip=True)
    
    # Рейтинг
    rating = tour.find('meta', itemprop='ratingValue')['content']
    rating_count = tour.find('meta', itemprop='ratingCount')['content']
    
    # Изображение
    image = tour.find('meta', itemprop='image')['content']
    
    # Все данные
    print(f"Название: {name}")
    print(f"URL: {full_url}")
    print(f"Цена: {price}")
    print(f"Даты: {dates}")
    print(f"Местоположение: {location}")
    print(f"Тип тура: {tour_type}")
    print(f"Рейтинг: {rating} (оценок: {rating_count})")
    print(f"Изображение: {image}")
    print(f"Описание: {description[:100]}...") 
    print("="*50)
# Out:
# Название: Все краски Байкала. Поход на байдарках вокруг полуострова Святой Нос
# URL: https://bolshayastrana.com/bajkal/vse-kraski-bajkala-pohod-na-bajdarkah-vokrug-poluostrova-svyatoj-nos-16027
# Цена: RUB 86,000
# Даты: 30 июня — 9 июля
# Местоположение: Байкал, Бурятия
# Тип тура: Комбинированные туры
# Рейтинг: 5 (оценок: 37)
# Изображение: https://imcdn.bolshayastrana.com/1200x00/BS_f537eaf739d4f158c128a578095d6d53affc43bb017882447650e4264927b69d.jpeg
# Описание: Увлекательный водный поход на байдарках вокруг самого крупного полуострова оз. Байкал — Святой Нос. ...
# ==================================================
# Название: Осетия и Ингушетия: нас не догонят. Комбинированный джип-тур на 3 дня
# URL: https://bolshayastrana.com/kavkaz/nas-ne-dogonyat-dzhip-tur-3-dnya-364307
# Цена: RUB 30,490
# Даты: 4—6 апреля
# Местоположение: Кавказ, Северная Осетия, Ингушетия
# Тип тура: Комбинированные туры
# Рейтинг: 5 (оценок: 147)
# Изображение: https://imcdn.bolshayastrana.com/1200x00/BS_67ec0212c8d5f063c7947e5183cc8863b7d143687a2f521e020a699429768441.jpeg
# Описание: Сборный джип-тур по республикам Северного Кавказа — Осетии и Ингушетии. Старинные здания и купечески...
# ==================================================
# Название: Байкальской тропой до долины вулканов
# URL: https://bolshayastrana.com/bajkal/bajkalskoj-tropoj-do-doliny-vulkanov-16029
# Цена: RUB 120,000
# Даты: 28 июня — 13 июля
# Местоположение: Байкал, Бурятия, Тыва (Тува)
# Тип тура: Комбинированные туры
# Рейтинг: 5 (оценок: 37)
# Изображение: https://icdn.bolshayastrana.com/1200x00/64/fd/64fdcce6e8ee02da13a5f9844394b07f.jpeg
# Описание: Вулканы, термальные источники, горы, первозданная природа — и все это на Байкале. Можете себе предст...
# ==================================================
# Название: Осетия и Ингушетия: нас не догонят. Комбинированный джип-тур
# URL: https://bolshayastrana.com/kavkaz/nas-ne-dogonyat-kombinirovannyj-dzip-tur-364283
# Цена: RUB 55,980
# Даты: 4—8 апреля
# Местоположение: Кавказ, Северная Осетия, Ингушетия
# Тип тура: Комбинированные туры
# Рейтинг: 5 (оценок: 147)
# Изображение: https://imcdn.bolshayastrana.com/1200x00/BS_1961966bd85187ca52a3f75252b2d1cdccc93ef60b46ea3fe4807eb0bfed92c4.jpeg
# Описание: Круглогодичная джип-программа по Кавказу. Начнем наше путешествие со столицы Осетии — Владикавказа, ...
# ==================================================
# Название: Мамисон. Экскурсионный тур в Северную Осетию
# URL: https://bolshayastrana.com/severnaya-osetiya/mamison-ekskursionnyj-tur-348966
# Цена: RUB 30,677
# Даты: 4—7 апреля
# Местоположение: Северная Осетия, Кавказ
# Тип тура: Экскурсионные туры
# Рейтинг: 5 (оценок: 147)
# Изображение: https://imcdn.bolshayastrana.com/1200x00/BS_9a3feed2958bdf07c323ef3aebd477a59a27607d40d1d8befcc1c095058d42d8.jpeg
# Описание: Отправляемся в увлекательное путешествие: Дигорское, Мамисонское и Цейское ущелья, уникальный монуме...
# ==================================================
# Название: Пробуждение Ольхона
# URL: https://bolshayastrana.com/bajkal/probuzhdenie-olhona-107929
# Цена: RUB 45,000
# Даты: 4—7 апреля
# Местоположение: Байкал
# Тип тура: Экскурсионные туры
# Рейтинг: 4.9 (оценок: 271)
# Изображение: https://imcdn.bolshayastrana.com/1200x00/BS_4d2dc7bdfdbab8e213b8bffbaed7d24ce5e90f4e4b21887c33e8aad82e63a3f1.jpeg
# Описание: Удивительный Ольхон – это самый большой и единственный населенный остров на Байкале.  В этом туре вы...
# ==================================================
# Название: Весенний Ольхон
# URL: https://bolshayastrana.com/bajkal/vesennij-olhon-111158
# Цена: RUB 29,900
# Даты: 4—6 апреля
# Местоположение: Байкал
# Тип тура: Экскурсионные туры
# Рейтинг: 4.9 (оценок: 267)
# Изображение: https://imcdn.bolshayastrana.com/1200x00/BS_b9504cec25add60a8d0fffc1ded3c578521d5c7a7013503d7b3906ce70312cd8.jpeg
# Описание: Классический тур по острову Ольхон на Байкале – это знакомство с центром Ольхона, его главными “мест...
# ==================================================
# Название: Дагестан на максимум. Вcе включено
# URL: https://bolshayastrana.com/dagestan/dagestan-na-maksimum-155588
# Цена: RUB 42,600
# Даты: 4—8 апреля
# Местоположение: Дагестан, Кавказ
# Тип тура: Комбинированные туры
# Рейтинг: 5 (оценок: 528)
# Изображение: https://imcdn.bolshayastrana.com/1200x00/BS_7d24aaf598709ff161780b4257b8909d2fb5d48e028bdff63a2762ab8557cc55.jpeg
# Описание: За 5 дней мы посетим все самые красивые локации и топовые смотровые площадки Дагестана, а также тайн...
# ==================================================
# Название: Весна в Карелии
# URL: https://bolshayastrana.com/kareliya/vesna-v-karelii-109326
# Цена: RUB 30,900
# Даты: 4—6 апреля
# Местоположение: Карелия
# Тип тура: Экскурсионные туры
# Рейтинг: 5 (оценок: